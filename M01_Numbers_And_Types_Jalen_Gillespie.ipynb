# %%
## 3.1
seconds_in_minute = 60
minutes_in_hour = 60

print("[3.1] Seconds in an hour:", seconds_in_minute * minutes_in_hour)

## 3.2
seconds_per_hour = seconds_in_minute * minutes_in_hour
print("[3.2] seconds_per_hour print:", seconds_per_hour)

## 3.3
print("[3.3] Seconds in a day:", seconds_per_hour * 24)

## 3.4
seconds_per_day = seconds_per_hour * 24
print("[3.4] seconds_per_day print:", seconds_per_day)

## 3.5
print("[3.5]:", seconds_per_day / seconds_per_hour)

## 3.6
print("[3.6]:", seconds_per_day // seconds_per_hour)

## 3.6 question (Did this number agree besides from the .0)
## A: Yes, both of the prints outputted the exact same number, besides one point a flo
# Out:
# [3.1] Seconds in an hour: 3600
# [3.2] seconds_per_hour print: 3600
# [3.3] Seconds in a day: 86400
# [3.4] seconds_per_day print: 86400
# [3.5]: 24.0
# [3.6]: 24
